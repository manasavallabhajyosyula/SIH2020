# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#Setting Warnings
import warnings
warnings.filterwarnings('ignore')

#Read the csv file
df=pd.read_csv('NSE-AMBIKCO.csv',index_col='Date',parse_dates=True)

# %%
df.head()
# Out:
#                Open     High      Low    Last    Close  Total Trade Quantity  \
# Date
# 2019-01-04  1159.05  1160.00  1131.00  1159.0  1157.50                1923.0
# 2019-01-03  1160.00  1160.00  1155.00  1155.0  1155.70                2021.0
# 2019-01-02  1160.00  1160.00  1155.00  1159.5  1159.25                1039.0
# 2019-01-01  1186.35  1186.40  1155.45  1160.0  1159.10                 748.0
# 2018-12-31  1159.00  1160.05  1155.00  1160.0  1159.25                1089.0
#
#             Turnover (Lacs)
# Date
# 2019-01-04            22.18
# 2019-01-03            23.42
# 2019-01-02            12.04
# 2019-01-01             8.68
# 2018-12-31            12.62

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2533 entries, 2019-01-04 to 2008-01-29
# Data columns (total 7 columns):
# Open                    2533 non-null float64
# High                    2533 non-null float64
# Low                     2533 non-null float64
# Last                    2533 non-null float64
# Close                   2533 non-null float64
# Total Trade Quantity    2533 non-null float64
# Turnover (Lacs)         2533 non-null float64
# dtypes: float64(7)
# memory usage: 158.3 KB

# %%
df.describe().T
# Out:
#                        count         mean           std    min      25%  \
# Open                  2533.0   534.936064    463.301793  36.25   168.00
# High                  2533.0   544.266423    468.932210  39.00   171.00
# Low                   2533.0   525.166739    456.351395  36.25   163.90
# Last                  2533.0   533.485156    461.541648  38.00   166.10
# Close                 2533.0   533.426273    461.530607  38.45   166.40
# Total Trade Quantity  2533.0  7833.202527  22990.183042   1.00  1050.00
# Turnover (Lacs)       2533.0    41.845645    112.351845   0.00     1.85
#
#                           50%      75%        max
# Open                   252.50   894.00    1755.00
# High                   258.00   911.00    1859.95
# Low                    245.55   873.00    1675.95
# Last                   250.00   892.00    1690.00
# Close                  250.85   893.70    1693.55
# Total Trade Quantity  2610.00  6239.00  598895.00
# Turnover (Lacs)         12.92    39.45    2255.58

# %%
data.describe()
# Out:
#               Open         High          Low         Last        Close  \
# count  2533.000000  2533.000000  2533.000000  2533.000000  2533.000000
# mean    534.936064   544.266423   525.166739   533.485156   533.426273
# std     463.301793   468.932210   456.351395   461.541648   461.530607
# min      36.250000    39.000000    36.250000    38.000000    38.450000
# 25%     168.000000   171.000000   163.900000   166.100000   166.400000
# 50%     252.500000   258.000000   245.550000   250.000000   250.850000
# 75%     894.000000   911.000000   873.000000   892.000000   893.700000
# max    1755.000000  1859.950000  1675.950000  1690.000000  1693.550000
#
#        Total Trade Quantity  Turnover (Lacs)
# count           2533.000000      2533.000000
# mean            7833.202527        41.845645
# std            22990.183042       112.351845
# min                1.000000         0.000000
# 25%             1050.000000         1.850000
# 50%             2610.000000        12.920000
# 75%             6239.000000        39.450000
# max           598895.000000      2255.580000

# %%
df.resample('MS')

# %%
df.tail()
# Out:
#               Open   High     Low   Last   Close  Total Trade Quantity  \
# Date
# 2008-02-04  127.40  138.0  127.00  135.2  135.20                2404.0
# 2008-02-01  130.00  138.0  127.00  127.3  127.30                 119.0
# 2008-01-31  126.00  133.0  126.00  132.0  132.00                 241.0
# 2008-01-30  135.05  138.5  131.25  133.0  133.00                 610.0
# 2008-01-29  141.00  149.2  139.80  146.0  142.65               29111.0
#
#             Turnover (Lacs)
# Date
# 2008-02-04             3.24
# 2008-02-01             0.16
# 2008-01-31             0.32
# 2008-01-30             0.82
# 2008-01-29            42.30

# %%
sns.set_style('darkgrid')
df['Close'].plot(figsize=(12,6),title='Closing Price',grid=True,colormap='coolwarm',legend=True);

# %%
#Let''s Plot Out Opening Price of Our Data
sns.set_style('darkgrid')
#df['Close'].plot(figsize=(12,8),title='Closing Price',grid=True,colormap='coolwarm',legend=True);
df['Open'].plot(figsize=(12,8),title='Closing Price',grid=True,colormap='viridis',legend=True);
